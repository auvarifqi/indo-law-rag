# %%
import os
import openai
from dotenv import load_dotenv
# Load environment variables from .env file
load_dotenv()

GROQ_API_KEY = os.environ.get("GROQ_API_KEY")
print(GROQ_API_KEY)
client = openai.OpenAI(
    base_url="https://api.groq.com/openai/v1",
    api_key=GROQ_API_KEY
)

# test
response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {"role": "system", "content": "You are a helpful legal assistant."},
        {"role": "user", "content": "Apa yang Anda ketahui tentang hukum korupsi di Indonesia?"}
    ],
    temperature=0.1,
    max_tokens=1024,
    stream=False
)
print(response.choices[0].message.content)
# Out:
# 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
# Hukum korupsi di Indonesia adalah seperangkat aturan dan regulasi yang bertujuan untuk mencegah dan menindak tindakan korupsi di Indonesia. Berikut beberapa hal yang saya ketahui tentang hukum korupsi di Indonesia:
#
# 1. **Undang-Undang No. 31 Tahun 1999**: Undang-undang ini merupakan dasar hukum utama untuk menangani korupsi di Indonesia. Undang-undang ini mendefinisikan korupsi sebagai "tindakan yang dilakukan oleh pejabat atau pegawai negeri yang menggunakan wewenang dan kekuasaannya untuk kepentingan pribadi atau kelompok".
# 2. **Komisi Pemberantasan Korupsi (KPK)**: KPK adalah lembaga independen yang dibentuk pada tahun 2002 untuk menangani korupsi di Indonesia. KPK memiliki wewenang untuk menyelidiki, menangkap, dan menuntut pelaku korupsi.
# 3. **Tindak pidana korupsi**: Tindak pidana korupsi di Indonesia meliputi:
#  * Penyuapan
#  * Pemerasan
#  * Penggelapan
#  * Penyalahgunaan wewenang
#  * Penggunaan jabatan untuk kepentingan pribadi
# 4. **Hukuman**: Hukuman untuk tindak pidana korupsi di Indonesia dapat berupa:
#  * Pidana penjara
#  * Denda
#  * Pencabutan hak-hak sipil
#  * Pengembalian kerugian negara
# 5. **Pencegahan korupsi**: Pemerintah Indonesia telah mengambil beberapa langkah untuk mencegah korupsi, seperti:
#  * Membentuk KPK
#  * Mengimplementasikan sistem pengawasan dan pengendalian internal
#  * Meningkatkan transparansi dan akuntabilitas dalam pengelolaan keuangan negara
#  * Membuat peraturan dan kebijakan anti-korupsi
# 6. **Peran masyarakat**: Masyarakat juga memiliki peran penting dalam pencegahan dan penindakan korupsi di Indonesia. Masyarakat dapat melaporkan tindakan korupsi kepada KPK atau lembaga lainnya, serta mendukung upaya pencegahan korupsi dengan meningkatkan kesadaran dan partisipasi dalam pengawasan dan pengendalian korupsi.
#
# Dengan demikian, hukum korupsi di Indonesia memiliki tujuan untuk mencegah dan menindak tindakan korupsi, serta meningkatkan transparansi dan akuntabilitas dalam pengelolaan keuangan negara.

# %%
from openai import OpenAI
OPENROUTER_API_KEY = os.environ.get("OPENROUTER_API_KEY")
client = OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key=OPENROUTER_API_KEY,
)
# test
response = client.chat.completions.create(
    model="google/gemma-3-27b-it:free",
    messages=[
        {"role": "system", "content": "You are a helpful legal assistant."},
        {"role": "user", "content": "Apa yang Anda ketahui tentang hukum korupsi di Indonesia?"}
    ],
    temperature=0.1,
    max_tokens=1024,
    stream=False
)
print(response.choices[0].message.content)
# Out:
# Tentu, saya bisa memberikan informasi mengenai hukum korupsi di Indonesia. Berikut adalah rangkuman mengenai hal tersebut:
#
# **Landasan Hukum Utama:**
#
# *   **Undang-Undang Nomor 31 Tahun 1999 tentang Pemberantasan Tindak Pidana Korupsi (UU Tipikor):** Ini adalah undang-undang utama yang mengatur tentang korupsi di Indonesia. UU ini telah beberapa kali diubah, terakhir melalui **Undang-Undang Nomor 20 Tahun 2001**.
# *   **Undang-Undang Nomor 30 Tahun 2002 tentang Komisi Pemberantasan Korupsi (UU KPK):**  UU ini mendirikan Komisi Pemberantasan Korupsi (KPK) sebagai lembaga independen yang bertugas memberantas korupsi.
# *   **Kitab Undang-Undang Hukum Pidana (KUHP):** Beberapa pasal dalam KUHP juga dapat diterapkan dalam kasus-kasus korupsi, terutama terkait dengan penyalahgunaan jabatan dan kekuasaan.
# *   **Peraturan Perundang-undangan Lainnya:**  Terdapat berbagai peraturan lain yang terkait dengan pencegahan dan pemberantasan korupsi, seperti peraturan mengenai gratifikasi, konflik kepentingan, dan laporan kekayaan pejabat negara.
#
# **Definisi Korupsi Menurut UU Tipikor:**
#
# UU Tipikor mendefinisikan korupsi secara luas, meliputi:
#
# *   **Penggelapan:**  Tindakan mengambil uang atau barang milik negara atau perusahaan secara tidak sah.
# *   **Penyuapan:**  Memberikan atau menerima sesuatu (uang, barang, atau janji) untuk mempengaruhi seseorang dalam menjalankan tugasnya.
# *   **Pemerasan:**  Memaksa seseorang untuk memberikan sesuatu dengan ancaman.
# *   **Penyalahgunaan Kewenangan:**  Menggunakan jabatan atau kekuasaan untuk keuntungan pribadi atau orang lain.
# *   **Pengkhianatan Amanah:**  Melanggar kepercayaan yang diberikan dalam jabatan.
# *   **Konflik Kepentingan:**  Situasi di mana kepentingan pribadi bertentangan dengan kepentingan publik.
# *   **Gratifikasi:**  Menerima hadiah atau pemberian yang berhubungan dengan jabatan dan berpotensi mempengaruhi keputusan. (Gratifikasi bisa menjadi tindak pidana jika tidak dilaporkan).
#
# **Pidana dan Sanksi:**
#
# Hukum korupsi di Indonesia memberikan sanksi yang berat bagi pelaku korupsi, termasuk:
#
# *   **Pidana Penjara:**  Mulai dari beberapa tahun hingga hukuman seumur hidup, tergantung pada jenis dan beratnya korupsi.
# *   **Denda:**  Jumlah denda bervariasi, bisa mencapai ratusan juta atau bahkan miliaran rupiah.
# *   **Penyitaan Aset:**  Aset yang diperoleh dari hasil korupsi dapat disita oleh negara.
# *   **Pemecatan:**  Pejabat negara yang terbukti korupsi dapat diberhentikan dari jabatannya.
# *   **Hukuman Tambahan:**  Seperti pencabutan hak untuk menduduki jabatan tertentu.
#
# **Lembaga yang Berperan dalam Pemberantasan Korupsi:**
#
# *   **Komisi Pemberantasan Korupsi (KPK):** Lembaga utama yang bertanggung jawab untuk menyelidiki, menuntut, dan mengadili kasus-kasus korupsi.
# *   **Kepolisian Republik Indonesia (Polri):**  Melakukan penyelidikan dan penyidikan kasus korupsi, terutama yang melibatkan pejabat daerah atau instansi pemerintah lainnya.
# *   **Kejaksaan Agung (Kejagung):**  Menuntut kasus-kasus korupsi di pengadilan.
# *   **Badan Pemeriksa Keuangan (BPK):**  Melakukan audit terhadap keuangan negara dan memberikan rekomendasi untuk perbaikan.
# *   **Pengadilan Tindak Pidana Korupsi (Tipikor):**  Mengadili kasus-kasus korupsi.
#
# **Perkembangan Terbaru:**
#
# *   **Revisi UU KPK:**  Revisi UU KPK yang disahkan pada tahun 2019 menimbulkan kontroversi karena dianggap melemahkan KPK. Beberapa ketentuan yang dipermasalahkan antara lain pembentukan Dewan Pengawas, pembatasan wewenang penyidikan, dan persyaratan minimal laporan penyelidikan.
# *   **Peningkatan Penggunaan Teknologi:**  KPK dan lembaga lainnya semakin memanfaatkan teknologi dalam pemberantasan korupsi, seperti sistem pelaporan online, analisis data, dan pemantauan transaksi keuangan.
#
# **Pencegahan Korupsi:**
#
# Selain penindakan, pencegahan korupsi juga menjadi fokus utama. Upaya pencegahan meliputi:
#
# *   **Peningkatan Transparansi dan Akuntabilitas:**  Meningkatkan keterbukaan informasi publik dan memastikan pertanggungjawaban pejabat publik.
# *   **Peningkatan Kualitas Pelayanan
